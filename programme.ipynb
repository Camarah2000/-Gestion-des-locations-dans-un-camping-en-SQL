# %% [markdown]
# <a href="https://colab.research.google.com/github/Camarah2000/-Gestion-des-locations-dans-un-camping-en-SQL/blob/main/programme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
scalaire_1=np.array(5)
scalaire_2=np.array(6)
resultat=scalaire_1+scalaire_2
print(resultat) #ce programme fait la somme de deux scalaires
# Out:
# 11

# %%
#Exercice2
v1=np.array([1,2,3])
v2=np.array([3,2,1])
v3=np.array([0,1,-1])
resultat=v1+v2+v3
print(resultat)
#il fait la somme des trois vecteur
# Out:
# [4 5 3]
